# %%
### python example
# Out:
# Running cells with 'venv (Python 3.12.0)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /Users/aadikatiyaan/Desktop/aadiProjects/GenAI/venv ipykernel --update-deps --force-reinstall'

# %%
1+2
# Out:
# 3

# %%
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
count  = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i == 3:
        print("Found 3, skipping it",i)
        pass
    print(i)
# Out:
# 0
# 1
# 2
# Found 3, skipping it 3
# 3
# 4
